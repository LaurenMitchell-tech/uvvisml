# %% [markdown]
# <a href="https://colab.research.google.com/github/LaurenMitchell-tech/uvvisml/blob/main/notebooks/CIE_Color_Plot_for_data_formatting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

if os.getenv("COLAB_RELEASE_TAG"):
    try:
        import chemprop
    except ImportError:
        # !git clone https://github.com/chemprop/chemprop.git
        # %cd chemprop
        # !pip install .

os.chdir('/content')
# !git clone https://github.com/learningmatter-mit/uvvisml
os.chdir('/content/uvvisml/uvvisml')
# Out:
# Cloning into 'chemprop'...
# remote: Enumerating objects: 25475, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 25475 (delta 131), reused 45 (delta 45), pack-reused 25255 (from 4)
# Receiving objects: 100% (25475/25475), 876.25 MiB | 31.20 MiB/s, done.
# Resolving deltas: 100% (18254/18254), done.
# Updating files: 100% (337/337), done.
# /content/chemprop
# Processing /content/chemprop
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting lightning>=2.0 (from chemprop==2.2.1)
#   Downloading lightning-2.6.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from chemprop==2.2.1) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from chemprop==2.2.1) (2.2.2)
# Collecting rdkit (from chemprop==2.2.1)
#   Downloading rdkit-2025.9.3-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from chemprop==2.2.1) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from chemprop==2.2.1) (1.16.3)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.12/dist-packages (from chemprop==2.2.1) (2.9.0+cpu)
# Collecting astartes[molecules] (from chemprop==2.2.1)
#   Downloading astartes-1.3.3-py3-none-any.whl.metadata (26 kB)
# Collecting ConfigArgParse (from chemprop==2.2.1)
#   Downloading configargparse-1.7.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from chemprop==2.2.1) (13.9.4)
# Collecting descriptastorus (from chemprop==2.2.1)
#   Downloading descriptastorus-2.8.0-py3-none-any.whl.metadata (364 bytes)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->chemprop==2.2.1) (6.0.3)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->chemprop==2.2.1) (2025.3.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.0->chemprop==2.2.1)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: packaging<27.0,>=20.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->chemprop==2.2.1) (25.0)
# Collecting torchmetrics<3.0,>0.7.0 (from lightning>=2.0->chemprop==2.2.1)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->chemprop==2.2.1) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->chemprop==2.2.1) (4.15.0)
# Collecting pytorch-lightning (from lightning>=2.0->chemprop==2.2.1)
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->chemprop==2.2.1) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->chemprop==2.2.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->chemprop==2.2.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->chemprop==2.2.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->chemprop==2.2.1) (3.1.6)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from astartes[molecules]->chemprop==2.2.1) (0.9.0)
# Collecting aimsim_core (from astartes[molecules]->chemprop==2.2.1)
#   Downloading aimsim_core-2.2.3-py3-none-any.whl.metadata (15 kB)
# Collecting pandas-flavor (from descriptastorus->chemprop==2.2.1)
#   Downloading pandas_flavor-0.8.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->chemprop==2.2.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->chemprop==2.2.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->chemprop==2.2.1) (2025.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit->chemprop==2.2.1) (11.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->chemprop==2.2.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->chemprop==2.2.1) (2.19.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->chemprop==2.2.1) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->chemprop==2.2.1) (3.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->chemprop==2.2.1) (3.13.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->chemprop==2.2.1) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->chemprop==2.2.1) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1->chemprop==2.2.1) (1.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from aimsim_core->astartes[molecules]->chemprop==2.2.1) (5.9.5)
# Collecting padelpy (from aimsim_core->astartes[molecules]->chemprop==2.2.1)
#   Downloading padelpy-0.1.16-py3-none-any.whl.metadata (7.7 kB)
# Collecting mhfp (from aimsim_core->astartes[molecules]->chemprop==2.2.1)
#   Downloading mhfp-1.9.6-py3-none-any.whl.metadata (9.0 kB)
# Collecting mordredcommunity (from aimsim_core->astartes[molecules]->chemprop==2.2.1)
#   Downloading mordredcommunity-2.0.6-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: multiprocess>=0.70 in /usr/local/lib/python3.12/dist-packages (from aimsim_core->astartes[molecules]->chemprop==2.2.1) (0.70.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1->chemprop==2.2.1) (3.0.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from pandas-flavor->descriptastorus->chemprop==2.2.1) (2025.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->chemprop==2.2.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->chemprop==2.2.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->chemprop==2.2.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->chemprop==2.2.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->chemprop==2.2.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->chemprop==2.2.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->chemprop==2.2.1) (1.22.0)
# Requirement already satisfied: dill>=0.3.8 in /usr/local/lib/python3.12/dist-packages (from multiprocess>=0.70->aimsim_core->astartes[molecules]->chemprop==2.2.1) (0.3.8)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->chemprop==2.2.1) (3.11)
# Downloading lightning-2.6.0-py3-none-any.whl (845 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 25.5 MB/s eta 0:00:00
# Downloading configargparse-1.7.1-py3-none-any.whl (25 kB)
# Downloading descriptastorus-2.8.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 83.5 MB/s eta 0:00:00
# Downloading rdkit-2025.9.3-cp312-cp312-manylinux_2_28_x86_64.whl (36.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 16.6 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 49.3 MB/s eta 0:00:00
# Downloading aimsim_core-2.2.3-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 13.2 MB/s eta 0:00:00
# Downloading astartes-1.3.3-py3-none-any.whl (38 kB)
# Downloading pandas_flavor-0.8.1-py3-none-any.whl (8.5 kB)
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 45.6 MB/s eta 0:00:00
# Downloading mhfp-1.9.6-py3-none-any.whl (9.7 kB)
# Downloading mordredcommunity-2.0.6-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 kB 14.0 MB/s eta 0:00:00
# Downloading padelpy-0.1.16-py3-none-any.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 43.9 MB/s eta 0:00:00
# Building wheels for collected packages: chemprop
#   Building wheel for chemprop (pyproject.toml) ... done
#   Created wheel for chemprop: filename=chemprop-2.2.1-py3-none-any.whl size=145570 sha256=2a6059de85b9b6eb4263fb6b8e9ccdec905b8d9157c7a73c16667ed05171cd87
#   Stored in directory: /tmp/pip-ephem-wheel-cache-247bb4ea/wheels/bb/1b/3a/c99d08e0979d004457bfb1fc38456c098c2f8b88f5aa4b541e
# Successfully built chemprop
# Installing collected packages: mhfp, rdkit, padelpy, lightning-utilities, ConfigArgParse, mordredcommunity, torchmetrics, astartes, aimsim_core, pytorch-lightning, pandas-flavor, lightning, descriptastorus, chemprop
# Successfully installed ConfigArgParse-1.7.1 aimsim_core-2.2.3 astartes-1.3.3 chemprop-2.2.1 descriptastorus-2.8.0 lightning-2.6.0 lightning-utilities-0.15.2 mhfp-1.9.6 mordredcommunity-2.0.6 padelpy-0.1.16 pandas-flavor-0.8.1 pytorch-lightning-2.6.0 rdkit-2025.9.3 torchmetrics-1.8.2
# Cloning into 'uvvisml'...
# remote: Enumerating objects: 154, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 154 (delta 16), reused 11 (delta 9), pack-reused 123 (from 1)
# Receiving objects: 100% (154/154), 9.32 MiB | 22.93 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
# ============================================================
# Multi-spectrum CIE 1931 chromaticity plot using
# Gaussian spectra defined in wavenumber space
# ============================================================

# !pip install colour-science pandas --quiet

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import colour
import math

# ---- Step 1: Load centers and bandwidths from CSV

csv_file = "data/original/joung/DB_for_chromophore_Sci_Data_rev02.csv"
data = pd.read_csv(csv_file, usecols=["Tag", "Chromophore", "Solvent", "Emission max (nm)", "emi FWHM (nm)", "emi FWHM (cm-1)"])

# ---- Step 2: Build spectra from formula ----
wavelengths = np.linspace(380, 780, 401)  # nanometers

spectra = {}

chrom = []
solvent = []

for _, row in data.iterrows():
    try:
        name = str(row["Tag"])
        L = float(row["Emission max (nm)"])
        S = float(row["emi FWHM (nm)"])
        cm = float(row["emi FWHM (cm-1)"])

        # Skip invalid rows
        if np.isnan(L) or np.isnan(S) or S == 0 or not np.isnan(cm):
            continue

        #S = S_nm/(L*1e-7)**2

        intensities = [
            math.exp(-4 * math.log(2) * (((W - L) / S) ** 2))
            for W in wavelengths
        ]

        spectra[name] = colour.SpectralDistribution(dict(zip(wavelengths, intensities)), name=name)

        chrom.append(row["Chromophore"])
        solvent.append(row["Solvent"])

    except:
        continue

# ---- Step 3: Define CMFs and Illuminant ----
cmfs = colour.MSDS_CMFS["CIE 1931 2 Degree Standard Observer"]
illuminant = colour.SDS_ILLUMINANTS["D65"]

# ---- Step 4: Compute XYZ and xyY for each spectrum ----
results = {}
for name, spectrum in spectra.items():
    XYZ = colour.sd_to_XYZ(spectrum, cmfs=cmfs, illuminant=illuminant)
    xyY = colour.XYZ_to_xyY(XYZ)
    results[name] = {"XYZ": XYZ, "xyY": xyY}

# ---- Step 5: Plot CIE 1931 diagram ----
colour.plotting.plot_chromaticity_diagram_CIE1931(standalone=False)

# ---- Step 6: Plot points as black dots ----
xs = []
ys =[]
for name, data in results.items():
    x, y = float(data["xyY"][0]), float(data["xyY"][1])
    xs.append(x)
    ys.append(y)
    if 0 <= x <= 0.8 and 0 <= y <= 0.9:
      plt.scatter([x], [y], color="black", s=10, zorder=10)

plt.show()

df = pd.DataFrame(list(zip(chrom, solvent, xs, ys)), columns=["Chromophore", "Solvent", "X", "Y"])
df
# Out:
# /usr/local/lib/python3.12/dist-packages/colour/utilities/verbose.py:340: ColourUsageWarning: "standalone" argument has been renamed to "show".
#   warn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/colour/utilities/verbose.py:340: ColourUsageWarning: "standalone" argument has been renamed to "show".
#   warn(*args, **kwargs)
#                                             Chromophore    Solvent         X  \
# 0                             N#Cc1cc2ccc([O-])cc2oc1=O          O  0.149727
# 1          [O-]c1c(-c2nc3ccccc3s2)cc2ccc3cccc4ccc1c2c34       CC#N  0.357314
# 2          [O-]c1c(-c2nc3ccccc3s2)cc2ccc3cccc4ccc1c2c34    CS(C)=O  0.355870
# 3                                        c1ccc2ccccc2c1   C1CCCCC1  0.174327
# 4                             C[Si](C)(C)c1cccc2ccccc12   C1CCCCC1  0.174370
# ...                                                 ...        ...       ...
# 7112  COc1ccc(C2=c3sc(-c4ccc(OC)cc4)cc3=[N+]3C2=Nc2c...  ClC(Cl)Cl  0.734690
# 7113  CC(C)(C)c1ccc(C2=c3sc(-c4ccc(C(C)(C)C)cc4)cc3=...  ClC(Cl)Cl  0.734690
# 7114  COc1ccc(C2=c3sc(-c4ccc(OC)cc4)c(-c4ccc(OC)cc4)...  ClC(Cl)Cl  0.734690
# 7115  CC(C)(C)c1ccc(C2=c3sc(-c4ccc(C(C)(C)C)cc4)c(-c...  ClC(Cl)Cl  0.734690
# 7116  CCC(C)[Si](C#Cc1c2cc3cc4c(cc3cc2c(C#C[Si](C(C)...     CCCCCC  0.734682
#
#              Y
# 0     0.029648
# 1     0.610118
# 2     0.629721
# 3     0.005065
# 4     0.005076
# ...        ...
# 7112  0.265310
# 7113  0.265310
# 7114  0.265310
# 7115  0.265310
# 7116  0.265318
#
# [7117 rows x 4 columns]

# %%
df.to_csv("Deep4Chem_CIE_Coordinates_FWHM(nm).csv", index=True)

# %%
from google.colab import files
files.download("Deep4Chem_CIE_Coordinates_FWHM(nm).csv")
